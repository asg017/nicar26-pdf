# %% [markdown]
# # Smoke test!
#
# Let's make sure your computer is up and running!
#
# Run the following cell, and if it prints "you're good" then, well, you're good!

# %%
import pdfplumber
import ocrmypdf
import part3_utils
_ = (pdfplumber, ocrmypdf, part3_utils)

print("🎉You're good!")
# Out:
# 🎉You're good!
